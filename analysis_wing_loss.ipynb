# %%
import torch
import matplotlib.pyplot as plt

# %%
def wing(x: torch.Tensor, w: torch.float, e: torch.float):
    c = w - w * torch.log(1 + w / e)
    
    if torch.abs(x) < w:
        result = w * torch.log(1 + torch.abs(x) / e)
    else:
        result = torch.abs(x) - c
        
    return result

# %%
w = 10
e = 2
x = torhc.arange(-20, 20, 0.1)
plt.plot(x, wing(x, w, e))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a7b8764ee3ed> in <module>
#       1 w = 10
#       2 e = 2
# ----> 3 x = torhc.arange(-20, 20, 0.1)
#       4 #
#
# NameError: name 'torhc' is not defined
