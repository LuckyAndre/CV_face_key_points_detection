# %%
# %pip install ipdb

# %%
from argparse import Namespace

# %%
#####################################
# Создание датасета для OCR
#####################################

# %%
import scripts.create_recognition_dataset

request = Namespace(
    data_dir='data/data',
    transform=False
)
scripts.create_recognition_dataset.main(request)
# Out:
# 100%|██████████| 25633/25633 [09:04<00:00, 47.05it/s]

# %%
#####################################
# Запуск обучения модели OCR
#####################################

# %%
from scripts.train_recognition import main

request = Namespace(
    data_path='data/data',
    epochs=24,
    batch_size=128,
    lr=3e-4,
    weight_decay=1e-5, # тут в 5ой, а на сегментации в 6ой
    lr_step=None,
    lr_gamma=None,
    input_wh='320x64',
    rotation=10,
    padding=0.1,
    load=None, # recognition_24ep.pth
    output_dir='runs/baseline_recognition'
)

# %%
#!g1.1
main(request)
# Out:
# 2021-09-04 14:11:59 Start training with params:
# 2021-09-04 14:11:59 Argument batch_size: 128
# 2021-09-04 14:11:59 Argument data_path: 'data/data'
# 2021-09-04 14:11:59 Argument epochs: 24
# 2021-09-04 14:11:59 Argument input_wh: '320x64'
# 2021-09-04 14:11:59 Argument load: None
# 2021-09-04 14:11:59 Argument lr: 0.0003
# 2021-09-04 14:11:59 Argument lr_gamma: None
# 2021-09-04 14:11:59 Argument lr_step: None
# 2021-09-04 14:11:59 Argument output_dir: 'runs/baseline_recognition'
# 2021-09-04 14:11:59 Argument padding: 0.1
# 2021-09-04 14:11:59 Argument rotation: 10
# 2021-09-04 14:11:59 Argument weight_decay: 1e-05
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /tmp/xdg_cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=46827520.0), HTML(value='')))
# 2021-09-04 14:12:03 Model type: CRNN
# 2021-09-04 14:12:03 Length of train / val = 21444/ 5361
# 2021-09-04 14:12:03 Number of batches of train / val = 168 / 42
# 2021-09-04 14:12:03 Starting epoch 1 / 24.
# mean loss: 2.2391: 100%|██████████| 168/168 [00:22<00:00,  7.50it/s]
# 2021-09-04 14:12:26 Epoch finished! Loss: 2.23909
# 100%|██████████| 42/42 [00:05<00:00,  8.08it/s]
# 2021-09-04 14:12:31 Valid acc: 0.13057, acc_ed: 1.71796 (best)
# 2021-09-04 14:12:31 Starting epoch 2 / 24.
# mean loss: 0.4094: 100%|██████████| 168/168 [00:17<00:00,  9.58it/s]
# 2021-09-04 14:12:49 Epoch finished! Loss: 0.40939
# 100%|██████████| 42/42 [00:02<00:00, 17.56it/s]
# 2021-09-04 14:12:52 Valid acc: 0.90002, acc_ed: 0.15128 (best)
# 2021-09-04 14:12:52 Starting epoch 3 / 24.
# mean loss: 0.1001: 100%|██████████| 168/168 [00:17<00:00,  9.58it/s]
# 2021-09-04 14:13:09 Epoch finished! Loss: 0.10007
# 100%|██████████| 42/42 [00:02<00:00, 17.46it/s]
# 2021-09-04 14:13:12 Valid acc: 0.92203, acc_ed: 0.11658 (best)
# 2021-09-04 14:13:12 Starting epoch 4 / 24.
# mean loss: 0.0601: 100%|██████████| 168/168 [00:17<00:00,  9.55it/s]
# 2021-09-04 14:13:30 Epoch finished! Loss: 0.06012
# 100%|██████████| 42/42 [00:02<00:00, 17.22it/s]
# 2021-09-04 14:13:33 Valid acc: 0.92781, acc_ed: 0.10558 (best)
# 2021-09-04 14:13:33 Starting epoch 5 / 24.
# mean loss: 0.0441: 100%|██████████| 168/168 [00:17<00:00,  9.59it/s]
# 2021-09-04 14:13:50 Epoch finished! Loss: 0.04409
# 100%|██████████| 42/42 [00:02<00:00, 17.56it/s]
# 2021-09-04 14:13:53 Valid acc: 0.92874, acc_ed: 0.10091 (best)
# 2021-09-04 14:13:53 Starting epoch 6 / 24.
# mean loss: 0.0343: 100%|██████████| 168/168 [00:17<00:00,  9.58it/s]
# 2021-09-04 14:14:10 Epoch finished! Loss: 0.03426
# 100%|██████████| 42/42 [00:02<00:00, 17.41it/s]
# 2021-09-04 14:14:13 Valid acc: 0.93583, acc_ed: 0.09327 (best)
# 2021-09-04 14:14:13 Starting epoch 7 / 24.
# mean loss: 0.0277: 100%|██████████| 168/168 [00:17<00:00,  9.65it/s]
# 2021-09-04 14:14:31 Epoch finished! Loss: 0.02772
# 100%|██████████| 42/42 [00:02<00:00, 17.63it/s]
# 2021-09-04 14:14:34 Valid acc: 0.93882, acc_ed: 0.09140 (best)
# 2021-09-04 14:14:34 Starting epoch 8 / 24.
# mean loss: 0.0234: 100%|██████████| 168/168 [00:17<00:00,  9.56it/s]
# 2021-09-04 14:14:51 Epoch finished! Loss: 0.02340
# 100%|██████████| 42/42 [00:02<00:00, 17.47it/s]
# 2021-09-04 14:14:54 Valid acc: 0.93136, acc_ed: 0.09998 (best 0.93882)
# 2021-09-04 14:14:54 Starting epoch 9 / 24.
# mean loss: 0.0226: 100%|██████████| 168/168 [00:17<00:00,  9.64it/s]
# 2021-09-04 14:15:11 Epoch finished! Loss: 0.02262
# 100%|██████████| 42/42 [00:02<00:00, 17.57it/s]
# 2021-09-04 14:15:13 Valid acc: 0.93192, acc_ed: 0.09979 (best 0.93882)
# 2021-09-04 14:15:13 Starting epoch 10 / 24.
# mean loss: 0.0166:   4%|▎         | 6/168 [00:01<00:34,  4.66it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8dcdaa05829d> in <module>
# ----> 1 main(request)
#       2 #
#
# ~/work/resources/contest02/scripts/train_recognition.py in main(args)
#     145         logger.info(f"Starting epoch {epoch + 1} / {args.epochs}.")
#     146
# --> 147         train_loss = train(model, criterion, optimizer, scheduler, train_dataloader, logger, device)
#     148         val_acc, val_acc_ed = validate(model, val_dataloader, device)
#     149
#
# ~/work/resources/contest02/scripts/train_recognition.py in train(model, criterion, optimizer, scheduler, train_dataloader, logger, device)
#      69     tqdm_iter = tqdm.tqdm(train_dataloader)
#      70     for i, batch in enumerate(tqdm_iter):
# ---> 71         images = batch["images"].to(device)
#      72         seqs = batch["seqs"]
#      73         seq_lens = batch["seq_lens"]
#
# KeyboardInterrupt:
