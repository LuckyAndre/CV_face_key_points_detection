# %%
# %pip install editdistance
# %pip install segmentation-models-pytorch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.

# %%
from argparse import Namespace

from scripts.create_submission import main

# %%
request = Namespace(
    data_path='data/data',
    seg_threshold=0.5,
    seg_model='runs/segmentation_data_10000_image_size_512_bce_075/CP-best.pth',
    rec_model='runs/recognition_levenshtein/CP-best.pth',
    input_wh='320x64',
    output_file='runs/segmentation_data_10000_image_size_512_bce_075/segmentation_data_10000_image_size_512_bce_075_submission.csv'
)

# %%
#!g1.1
main(request)
# Out:
# Start inference
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /tmp/xdg_cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /tmp/xdg_cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# ...
# 100%|█████████▉| 3155/3157 [02:52<00:00, 17.29it/s]
# Done
# 100%|██████████| 3157/3157 [02:52<00:00, 18.29it/s]

# %%
request = Namespace(
    data_path='data/data',
    seg_threshold=0.5,
    seg_model='runs/segmentation_data_10000_image_size_512_bce_025/CP-best.pth',
    rec_model='runs/recognition_levenshtein/CP-best.pth',
    input_wh='320x64',
    output_file='runs/segmentation_data_10000_image_size_512_bce_025/segmentation_data_10000_image_size_512_bce_025_submission.csv'
)

# %%
#!g1.1
main(request)
# Out:
# Start inference
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /tmp/xdg_cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /tmp/xdg_cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# ...
# 100%|█████████▉| 3151/3157 [02:33<00:00, 21.37it/s]
# Done
# 100%|██████████| 3157/3157 [02:34<00:00, 20.47it/s]

# %%
request = Namespace(
    data_path='data/data',
    seg_threshold=0.5,
    seg_model='runs/segmentation_image_size_512_bce_05/CP-best.pth',
    rec_model='runs/recognition_levenshtein/CP-best.pth',
    input_wh='320x64',
    output_file='runs/segmentation_image_size_512_bce_05/segmentation_image_size_512_bce_05_submission.csv'
)

# %%
#!g1.1
main(request)
# Out:
# Start inference
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /tmp/xdg_cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /tmp/xdg_cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# ...
# 100%|█████████▉| 3154/3157 [02:32<00:00, 18.22it/s]
# Done
# 100%|██████████| 3157/3157 [02:33<00:00, 20.62it/s]
