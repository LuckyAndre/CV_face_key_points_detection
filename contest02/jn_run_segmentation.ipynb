# %%
from argparse import Namespace

# %%
#####################################
# Создание сегментационного датасета
#####################################

# %%
# import scripts.create_segmentation_dataset

# request = Namespace(
#     data_dir='data/data',
# )
# scripts.create_segmentation_dataset.main(request)

# %%
########################################
# Запуск обучения сегментационной модели
########################################
# Out:
# 100%|██████████| 25633/25633 [12:11<00:00, 35.03it/s]

# %%
from scripts.train_segmentation import main

request = Namespace(
    data_path='data/data',
    epochs=10,
    batch_size=64, #128,
    image_size=512,
    lr=3e-4,
    weight_decay=1e-6,
    lr_step=None,
    lr_gamma=None,
    weight_bce=1,
    load=None, # 'baseline_models/segmentation_10ep.pth',
    output_dir='runs/segmentation_image_size_512'
)

# %%
#!g1.1
main(request)
# Out:
# 2021-09-05 12:02:16 Start training with params:
# 2021-09-05 12:02:16 Argument batch_size: 64
# 2021-09-05 12:02:16 Argument data_path: 'data/data'
# 2021-09-05 12:02:16 Argument epochs: 10
# 2021-09-05 12:02:16 Argument image_size: 512
# 2021-09-05 12:02:16 Argument load: None
# 2021-09-05 12:02:16 Argument lr: 0.0003
# 2021-09-05 12:02:16 Argument lr_gamma: None
# 2021-09-05 12:02:16 Argument lr_step: None
# 2021-09-05 12:02:16 Argument output_dir: 'runs/segmentation_image_size_512'
# 2021-09-05 12:02:16 Argument weight_bce: 1
# 2021-09-05 12:02:16 Argument weight_decay: 1e-06
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /tmp/xdg_cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=87306240.0), HTML(value='')))
# 2021-09-05 12:02:21 Model type: Unet
# 2021-09-05 12:02:21 Length of train / val = 20505 / 5127
# 2021-09-05 12:02:21 Number of batches of train / val = 320 / 81
# 2021-09-05 12:02:21 Starting epoch 1/10.
# mean loss: 0.1242: 100%|██████████| 320/320 [09:10<00:00,  1.72s/it]
# 2021-09-05 12:11:31 Epoch finished! Loss: 0.12425 (0.12425 | 0.00000)
# 100%|██████████| 81/81 [01:46<00:00,  1.31s/it]
# 2021-09-05 12:13:19 Validation Dice Coeff: 0.916 (best)
# 2021-09-05 12:13:19 Starting epoch 2/10.
# mean loss: 0.0213:  41%|████      | 130/320 [04:08<06:03,  1.91s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8dcdaa05829d> in <module>
# ----> 1 main(request)
#       2 #
#
# ~/work/resources/contest02/scripts/train_segmentation.py in main(args)
#     128         logger.info(f"Starting epoch {epoch + 1}/{args.epochs}.")
#     129
# --> 130         train_loss = train(model, optimizer, criterion, scheduler, train_dataloader, logger, device)
#     131
#     132         val_dice = validate(model, val_dataloader, device)
#
# ~/work/resources/contest02/scripts/train_segmentation.py in train(model, optimizer, criterion, scheduler, train_dataloader, logger, device)
#      66
#      67         optimizer.zero_grad()
# ---> 68         loss.backward()
#      69         optimizer.step()
#      70
#
# /usr/local/lib/python3.7/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#     129
#
# KeyboardInterrupt:
